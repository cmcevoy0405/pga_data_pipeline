# %%
# Import libraries 
import requests
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv

# %%
# Define API details
load_dotenv()

X_API_KEY = os.getenv('X_API_KEY')
url = "https://orchestrator.pgatour.com/graphql"
headers = {
    "x-api-key": X_API_KEY
}

# %%
# Data to scrape
stats_to_fetch = {
    "120": "avg_score",
    "138": "top_10",
    "101": "drive_dist",
    "102": "drive_acc",
    "119": "putts_per_round",
    "130": "scramble",
    "103": "gir",
    "160": "bounce_back",
    "02675": "strokes_gained",
    "02567": "strokes_gained_ot",
    "02569": "strokes_gained_arg",
    "02674": "strokes_gained_ttg",
    "02568": "strokes_gained_atg",
    "02564": "strokes_gained_putt",
    "142": "par3_score",
    "143": "par4_score",
    "144": "par5_score"
}

# %%
# Function to scrape multiple stats and years
def fetch_player_stat(stat_id, year):
    payload = {
        "operationName": "StatDetails",
        "variables": {
            "tourCode": "R",
            "statId": stat_id,
            "year": year,
            "eventQuery": None
        },
        "query": """
            query StatDetails($tourCode: TourCode!, $statId: String!, $year: Int, $eventQuery: StatDetailEventQuery) {
            statDetails(
                tourCode: $tourCode
                statId: $statId
                year: $year
                eventQuery: $eventQuery
            ) {
                rows {
                ... on StatDetailsPlayer {
                    playerId
                    playerName
                    country
                    rank
                    stats {
                        statName
                        statValue
                    }
                }
                }
            }
            }
        """
    }   

    response = requests.post(url, json=payload, headers=headers)
    if response.status_code != 200:
        print(f"API error for {stat_id} ({year}): {response.status_code}")
        return []

    data = response.json()
    rows = data.get('data', {}).get('statDetails', {}).get('rows', [])
    
    player_stats = []
    for row in rows:
        if 'playerName' in row:
            # Keep raw values as-is
            for s in row['stats']:
                player_stats.append({
                    'player_id': row['playerId'],
                    'player_name': row['playerName'],
                    'country': row.get('country'),
                    'year': year,
                    'rank': row.get('rank'),
                    'stat_id': stat_id,
                    'stat_name': stats_to_fetch.get(stat_id, f"stat_{stat_id}"),
                    'stat_value': s['statValue'],  # Keep raw string
                    'scraped_at': datetime.now()
                })
    
    print(f"Fetched {len(player_stats)} rows for {stat_id} ({year})")
    return player_stats

# %%
# Define years to scrape
start_year = datetime.now().year - 20
end_year = datetime.now().year

# To store all data
all_stats = []

# Nested Loop through years and stat's
for year in range(start_year, end_year + 1):
    for stat_id in stats_to_fetch.keys():
        all_stats.extend(fetch_player_stat(stat_id, year))

print(f'All data scraped between {start_year} and {end_year}')

df = pd.DataFrame(all_stats)
# Out:
# Fetched 808 rows for 120 (2005)
# Fetched 748 rows for 138 (2005)
# Fetched 606 rows for 101 (2005)
# Fetched 606 rows for 102 (2005)
# Fetched 808 rows for 119 (2005)
# Fetched 606 rows for 130 (2005)
# Fetched 808 rows for 103 (2005)
# Fetched 202 rows for 160 (2005)
# Fetched 1010 rows for 02675 (2005)
# Fetched 606 rows for 02567 (2005)
# Fetched 606 rows for 02569 (2005)
# Fetched 1010 rows for 02674 (2005)
# Fetched 606 rows for 02568 (2005)
# Fetched 606 rows for 02564 (2005)
# Fetched 606 rows for 142 (2005)
# Fetched 606 rows for 143 (2005)
# Fetched 606 rows for 144 (2005)
# Fetched 784 rows for 120 (2006)
# Fetched 740 rows for 138 (2006)
# Fetched 588 rows for 101 (2006)
# Fetched 588 rows for 102 (2006)
# Fetched 784 rows for 119 (2006)
# Fetched 588 rows for 130 (2006)
# Fetched 784 rows for 103 (2006)
# Fetched 196 rows for 160 (2006)
# Fetched 980 rows for 02675 (2006)
# Fetched 588 rows for 02567 (2006)
# Fetched 588 rows for 02569 (2006)
# Fetched 980 rows for 02674 (2006)
# Fetched 588 rows for 02568 (2006)
# Fetched 588 rows for 02564 (2006)
# Fetched 588 rows for 142 (2006)
# Fetched 588 rows for 143 (2006)
# Fetched 588 rows for 144 (2006)
# Fetched 784 rows for 120 (2007)
# Fetched 540 rows for 138 (2007)
# Fetched 588 rows for 101 (2007)
# Fetched 588 rows for 102 (2007)
# Fetched 784 rows for 119 (2007)
# Fetched 588 rows for 130 (2007)
# Fetched 784 rows for 103 (2007)
# Fetched 196 rows for 160 (2007)
# Fetched 980 rows for 02675 (2007)
# Fetched 588 rows for 02567 (2007)
# Fetched 588 rows for 02569 (2007)
# Fetched 980 rows for 02674 (2007)
# Fetched 588 rows for 02568 (2007)
# Fetched 588 rows for 02564 (2007)
# Fetched 588 rows for 142 (2007)
# Fetched 588 rows for 143 (2007)
# Fetched 588 rows for 144 (2007)
# Fetched 788 rows for 120 (2008)
# Fetched 564 rows for 138 (2008)
# Fetched 591 rows for 101 (2008)
# Fetched 591 rows for 102 (2008)
# Fetched 788 rows for 119 (2008)
# Fetched 591 rows for 130 (2008)
# Fetched 788 rows for 103 (2008)
# Fetched 197 rows for 160 (2008)
# Fetched 985 rows for 02675 (2008)
# Fetched 591 rows for 02567 (2008)
# Fetched 591 rows for 02569 (2008)
# Fetched 985 rows for 02674 (2008)
# Fetched 591 rows for 02568 (2008)
# Fetched 591 rows for 02564 (2008)
# Fetched 591 rows for 142 (2008)
# Fetched 591 rows for 143 (2008)
# Fetched 591 rows for 144 (2008)
# Fetched 736 rows for 120 (2009)
# Fetched 573 rows for 138 (2009)
# Fetched 552 rows for 101 (2009)
# Fetched 552 rows for 102 (2009)
# Fetched 736 rows for 119 (2009)
# Fetched 552 rows for 130 (2009)
# Fetched 736 rows for 103 (2009)
# Fetched 184 rows for 160 (2009)
# Fetched 920 rows for 02675 (2009)
# Fetched 552 rows for 02567 (2009)
# Fetched 552 rows for 02569 (2009)
# Fetched 920 rows for 02674 (2009)
# Fetched 552 rows for 02568 (2009)
# Fetched 552 rows for 02564 (2009)
# Fetched 552 rows for 142 (2009)
# Fetched 552 rows for 143 (2009)
# Fetched 552 rows for 144 (2009)
# Fetched 768 rows for 120 (2010)
# Fetched 780 rows for 138 (2010)
# Fetched 576 rows for 101 (2010)
# Fetched 576 rows for 102 (2010)
# Fetched 768 rows for 119 (2010)
# Fetched 576 rows for 130 (2010)
# Fetched 768 rows for 103 (2010)
# Fetched 192 rows for 160 (2010)
# Fetched 960 rows for 02675 (2010)
# Fetched 576 rows for 02567 (2010)
# Fetched 576 rows for 02569 (2010)
# Fetched 960 rows for 02674 (2010)
# Fetched 576 rows for 02568 (2010)
# Fetched 576 rows for 02564 (2010)
# Fetched 576 rows for 142 (2010)
# Fetched 576 rows for 143 (2010)
# Fetched 576 rows for 144 (2010)
# Fetched 744 rows for 120 (2011)
# Fetched 708 rows for 138 (2011)
# Fetched 558 rows for 101 (2011)
# Fetched 558 rows for 102 (2011)
# Fetched 744 rows for 119 (2011)
# Fetched 558 rows for 130 (2011)
# Fetched 744 rows for 103 (2011)
# Fetched 186 rows for 160 (2011)
# Fetched 930 rows for 02675 (2011)
# Fetched 558 rows for 02567 (2011)
# Fetched 558 rows for 02569 (2011)
# Fetched 930 rows for 02674 (2011)
# Fetched 558 rows for 02568 (2011)
# Fetched 558 rows for 02564 (2011)
# Fetched 558 rows for 142 (2011)
# Fetched 558 rows for 143 (2011)
# Fetched 558 rows for 144 (2011)
# Fetched 764 rows for 120 (2012)
# Fetched 728 rows for 138 (2012)
# Fetched 573 rows for 101 (2012)
# Fetched 573 rows for 102 (2012)
# Fetched 764 rows for 119 (2012)
# Fetched 573 rows for 130 (2012)
# Fetched 764 rows for 103 (2012)
# Fetched 191 rows for 160 (2012)
# Fetched 955 rows for 02675 (2012)
# Fetched 573 rows for 02567 (2012)
# Fetched 573 rows for 02569 (2012)
# Fetched 955 rows for 02674 (2012)
# Fetched 573 rows for 02568 (2012)
# Fetched 573 rows for 02564 (2012)
# Fetched 573 rows for 142 (2012)
# Fetched 573 rows for 143 (2012)
# Fetched 573 rows for 144 (2012)
# Fetched 720 rows for 120 (2013)
# Fetched 522 rows for 138 (2013)
# Fetched 540 rows for 101 (2013)
# Fetched 540 rows for 102 (2013)
# Fetched 720 rows for 119 (2013)
# Fetched 540 rows for 130 (2013)
# Fetched 720 rows for 103 (2013)
# Fetched 180 rows for 160 (2013)
# Fetched 900 rows for 02675 (2013)
# Fetched 540 rows for 02567 (2013)
# Fetched 540 rows for 02569 (2013)
# Fetched 900 rows for 02674 (2013)
# Fetched 540 rows for 02568 (2013)
# Fetched 540 rows for 02564 (2013)
# Fetched 540 rows for 142 (2013)
# Fetched 540 rows for 143 (2013)
# Fetched 540 rows for 144 (2013)
# Fetched 708 rows for 120 (2014)
# Fetched 525 rows for 138 (2014)
# Fetched 531 rows for 101 (2014)
# Fetched 531 rows for 102 (2014)
# Fetched 708 rows for 119 (2014)
# Fetched 531 rows for 130 (2014)
# Fetched 708 rows for 103 (2014)
# Fetched 177 rows for 160 (2014)
# Fetched 885 rows for 02675 (2014)
# Fetched 531 rows for 02567 (2014)
# Fetched 531 rows for 02569 (2014)
# Fetched 885 rows for 02674 (2014)
# Fetched 531 rows for 02568 (2014)
# Fetched 531 rows for 02564 (2014)
# Fetched 531 rows for 142 (2014)
# Fetched 531 rows for 143 (2014)
# Fetched 531 rows for 144 (2014)
# Fetched 736 rows for 120 (2015)
# Fetched 756 rows for 138 (2015)
# Fetched 552 rows for 101 (2015)
# Fetched 552 rows for 102 (2015)
# Fetched 736 rows for 119 (2015)
# Fetched 552 rows for 130 (2015)
# Fetched 736 rows for 103 (2015)
# Fetched 184 rows for 160 (2015)
# Fetched 920 rows for 02675 (2015)
# Fetched 552 rows for 02567 (2015)
# Fetched 552 rows for 02569 (2015)
# Fetched 920 rows for 02674 (2015)
# Fetched 552 rows for 02568 (2015)
# Fetched 552 rows for 02564 (2015)
# Fetched 552 rows for 142 (2015)
# Fetched 552 rows for 143 (2015)
# Fetched 552 rows for 144 (2015)
# Fetched 740 rows for 120 (2016)
# Fetched 728 rows for 138 (2016)
# Fetched 555 rows for 101 (2016)
# Fetched 555 rows for 102 (2016)
# Fetched 740 rows for 119 (2016)
# Fetched 555 rows for 130 (2016)
# Fetched 740 rows for 103 (2016)
# Fetched 185 rows for 160 (2016)
# Fetched 925 rows for 02675 (2016)
# Fetched 555 rows for 02567 (2016)
# Fetched 555 rows for 02569 (2016)
# Fetched 925 rows for 02674 (2016)
# Fetched 555 rows for 02568 (2016)
# Fetched 555 rows for 02564 (2016)
# Fetched 555 rows for 142 (2016)
# Fetched 555 rows for 143 (2016)
# Fetched 555 rows for 144 (2016)
# Fetched 760 rows for 120 (2017)
# Fetched 768 rows for 138 (2017)
# Fetched 570 rows for 101 (2017)
# Fetched 570 rows for 102 (2017)
# Fetched 760 rows for 119 (2017)
# Fetched 570 rows for 130 (2017)
# Fetched 760 rows for 103 (2017)
# Fetched 190 rows for 160 (2017)
# Fetched 950 rows for 02675 (2017)
# Fetched 570 rows for 02567 (2017)
# Fetched 570 rows for 02569 (2017)
# Fetched 950 rows for 02674 (2017)
# Fetched 570 rows for 02568 (2017)
# Fetched 570 rows for 02564 (2017)
# Fetched 570 rows for 142 (2017)
# Fetched 570 rows for 143 (2017)
# Fetched 570 rows for 144 (2017)
# Fetched 772 rows for 120 (2018)
# Fetched 732 rows for 138 (2018)
# Fetched 579 rows for 101 (2018)
# Fetched 579 rows for 102 (2018)
# Fetched 772 rows for 119 (2018)
# Fetched 579 rows for 130 (2018)
# Fetched 772 rows for 103 (2018)
# Fetched 193 rows for 160 (2018)
# Fetched 965 rows for 02675 (2018)
# Fetched 579 rows for 02567 (2018)
# Fetched 579 rows for 02569 (2018)
# Fetched 965 rows for 02674 (2018)
# Fetched 579 rows for 02568 (2018)
# Fetched 579 rows for 02564 (2018)
# Fetched 579 rows for 142 (2018)
# Fetched 579 rows for 143 (2018)
# Fetched 579 rows for 144 (2018)
# Fetched 752 rows for 120 (2019)
# Fetched 597 rows for 138 (2019)
# Fetched 564 rows for 101 (2019)
# Fetched 564 rows for 102 (2019)
# Fetched 752 rows for 119 (2019)
# Fetched 564 rows for 130 (2019)
# Fetched 752 rows for 103 (2019)
# Fetched 188 rows for 160 (2019)
# Fetched 940 rows for 02675 (2019)
# Fetched 564 rows for 02567 (2019)
# Fetched 564 rows for 02569 (2019)
# Fetched 940 rows for 02674 (2019)
# Fetched 564 rows for 02568 (2019)
# Fetched 564 rows for 02564 (2019)
# Fetched 564 rows for 142 (2019)
# Fetched 564 rows for 143 (2019)
# Fetched 564 rows for 144 (2019)
# Fetched 772 rows for 120 (2020)
# Fetched 648 rows for 138 (2020)
# Fetched 579 rows for 101 (2020)
# Fetched 579 rows for 102 (2020)
# Fetched 772 rows for 119 (2020)
# Fetched 579 rows for 130 (2020)
# Fetched 772 rows for 103 (2020)
# Fetched 193 rows for 160 (2020)
# Fetched 965 rows for 02675 (2020)
# Fetched 579 rows for 02567 (2020)
# Fetched 579 rows for 02569 (2020)
# Fetched 965 rows for 02674 (2020)
# Fetched 579 rows for 02568 (2020)
# Fetched 579 rows for 02564 (2020)
# Fetched 579 rows for 142 (2020)
# Fetched 579 rows for 143 (2020)
# Fetched 579 rows for 144 (2020)
# Fetched 784 rows for 120 (2021)
# Fetched 724 rows for 138 (2021)
# Fetched 588 rows for 101 (2021)
# Fetched 588 rows for 102 (2021)
# Fetched 784 rows for 119 (2021)
# Fetched 588 rows for 130 (2021)
# Fetched 784 rows for 103 (2021)
# Fetched 196 rows for 160 (2021)
# Fetched 980 rows for 02675 (2021)
# Fetched 588 rows for 02567 (2021)
# Fetched 588 rows for 02569 (2021)
# Fetched 980 rows for 02674 (2021)
# Fetched 588 rows for 02568 (2021)
# Fetched 588 rows for 02564 (2021)
# Fetched 588 rows for 142 (2021)
# Fetched 588 rows for 143 (2021)
# Fetched 588 rows for 144 (2021)
# Fetched 764 rows for 120 (2022)
# Fetched 776 rows for 138 (2022)
# Fetched 579 rows for 101 (2022)
# Fetched 579 rows for 102 (2022)
# Fetched 772 rows for 119 (2022)
# Fetched 579 rows for 130 (2022)
# Fetched 772 rows for 103 (2022)
# Fetched 193 rows for 160 (2022)
# Fetched 965 rows for 02675 (2022)
# Fetched 579 rows for 02567 (2022)
# Fetched 579 rows for 02569 (2022)
# Fetched 965 rows for 02674 (2022)
# Fetched 579 rows for 02568 (2022)
# Fetched 579 rows for 02564 (2022)
# Fetched 579 rows for 142 (2022)
# Fetched 579 rows for 143 (2022)
# Fetched 579 rows for 144 (2022)
# Fetched 772 rows for 120 (2023)
# Fetched 784 rows for 138 (2023)
# Fetched 579 rows for 101 (2023)
# Fetched 579 rows for 102 (2023)
# Fetched 772 rows for 119 (2023)
# Fetched 579 rows for 130 (2023)
# Fetched 772 rows for 103 (2023)
# Fetched 193 rows for 160 (2023)
# Fetched 965 rows for 02675 (2023)
# Fetched 579 rows for 02567 (2023)
# Fetched 579 rows for 02569 (2023)
# Fetched 965 rows for 02674 (2023)
# Fetched 579 rows for 02568 (2023)
# Fetched 579 rows for 02564 (2023)
# Fetched 579 rows for 142 (2023)
# Fetched 579 rows for 143 (2023)
# Fetched 579 rows for 144 (2023)
# Fetched 736 rows for 120 (2024)
# Fetched 744 rows for 138 (2024)
# Fetched 552 rows for 101 (2024)
# Fetched 552 rows for 102 (2024)
# Fetched 736 rows for 119 (2024)
# Fetched 552 rows for 130 (2024)
# Fetched 736 rows for 103 (2024)
# Fetched 184 rows for 160 (2024)
# Fetched 920 rows for 02675 (2024)
# Fetched 552 rows for 02567 (2024)
# Fetched 552 rows for 02569 (2024)
# Fetched 920 rows for 02674 (2024)
# Fetched 552 rows for 02568 (2024)
# Fetched 552 rows for 02564 (2024)
# Fetched 552 rows for 142 (2024)
# Fetched 552 rows for 143 (2024)
# Fetched 552 rows for 144 (2024)
# Fetched 660 rows for 120 (2025)
# Fetched 704 rows for 138 (2025)
# Fetched 495 rows for 101 (2025)
# Fetched 495 rows for 102 (2025)
# Fetched 660 rows for 119 (2025)
# Fetched 495 rows for 130 (2025)
# Fetched 660 rows for 103 (2025)
# Fetched 165 rows for 160 (2025)
# Fetched 825 rows for 02675 (2025)
# Fetched 495 rows for 02567 (2025)
# Fetched 495 rows for 02569 (2025)
# Fetched 825 rows for 02674 (2025)
# Fetched 495 rows for 02568 (2025)
# Fetched 495 rows for 02564 (2025)
# Fetched 495 rows for 142 (2025)
# Fetched 495 rows for 143 (2025)
# Fetched 495 rows for 144 (2025)
# All data scraped between 2005 and 2025

# %%
df.to_csv('golf_data.csv', index = False)
